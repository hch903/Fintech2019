# %%
import pandas as pd
import time
from datetime import timedelta
import datetime
import xlwt

# %%
raw_stock_data_2018 = pd.read_excel("stock_data.xlsx", sheet_name="上市2018")
raw_stock_data_2017 = pd.read_excel("stock_data.xlsx", sheet_name="上市2017")
raw_stock_data_2016 = pd.read_excel("stock_data.xlsx", sheet_name="上市2016")
df_2018 = pd.DataFrame(raw_stock_data_2018)
df_2017 = pd.DataFrame(raw_stock_data_2017)
df_2016 = pd.DataFrame(raw_stock_data_2016)

# %%
df_2018
# Out:
#                     證券代碼        年月日    開盤價(元)    最高價(元)    最低價(元)    收盤價(元)  \
# 0                1101 台泥 2018-12-28     35.40     35.75     35.40     35.60
# 1                1102 亞泥 2018-12-28     33.55     34.30     33.55     33.95
# 2                1103 嘉泥 2018-12-28     13.50     13.60     13.45     13.60
# 3                1104 環泥 2018-12-28     18.80     18.90     18.80     18.90
# 4                1108 幸福 2018-12-28      7.34      7.35      7.34      7.34
# 5                1109 信大 2018-12-28     13.95     13.95     13.60     13.80
# 6                1110 東泥 2018-12-28     17.00     17.00     16.80     16.95
# 7                1201 味全 2018-12-28     22.00     22.25     21.50     22.25
# 8                1203 味王 2018-12-28     25.95     26.00     25.95     26.00
# 9                1210 大成 2018-12-28     33.50     33.55     33.05     33.50
# 10               1213 大飲 2018-12-28     10.05     10.05     10.05     10.05
# ...

# %%
df_tsmc = pd.DataFrame(columns=['證券代碼','年月日','開盤價(元)','收盤價(元)'])
j = 0
for index, row in df_2018.iterrows():
    if row['證券代碼'] == '2330 台積電':
        df_tsmc.loc[j] = row
        j += 1
for index, row in df_2017.iterrows():
    if row['證券代碼'] == '2330 台積電':
        df_tsmc.loc[j] = row
        j += 1
for index, row in df_2016.iterrows():
    if row['證券代碼'] == '2330 台積電':
        df_tsmc.loc[j] = row
        j += 1

# %%
df_foxconn = pd.DataFrame(columns=['證券代碼','年月日','開盤價(元)','收盤價(元)'])
j = 0
for index, row in df_2018.iterrows():
    if row['證券代碼'] == '2317 鴻海':
        df_foxconn.loc[j] = row
        j += 1
for index, row in df_2017.iterrows():
    if row['證券代碼'] == '2317 鴻海':
        df_foxconn.loc[j] = row
        j += 1
for index, row in df_2016.iterrows():
    if row['證券代碼'] == '2317 鴻海':
        df_foxconn.loc[j] = row
        j += 1

# %%
df_fpc = pd.DataFrame(columns=['證券代碼','年月日','開盤價(元)','收盤價(元)'])
j = 0
for index, row in df_2018.iterrows():
    if row['證券代碼'] == '1301 台塑':
        df_fpc.loc[j] = row
        j += 1
for index, row in df_2017.iterrows():
    if row['證券代碼'] == '1301 台塑':
        df_fpc.loc[j] = row
        j += 1
for index, row in df_2016.iterrows():
    if row['證券代碼'] == '1301 台塑':
        df_fpc.loc[j] = row
        j += 1

# %%
df_largan = pd.DataFrame(columns=['證券代碼','年月日','開盤價(元)','收盤價(元)'])
j = 0
for index, row in df_2018.iterrows():
    if row['證券代碼'] == '3008 大立光':
        df_largan.loc[j] = row
        j += 1
for index, row in df_2017.iterrows():
    if row['證券代碼'] == '3008 大立光':
        df_largan.loc[j] = row
        j += 1
for index, row in df_2016.iterrows():
    if row['證券代碼'] == '3008 大立光':
        df_largan.loc[j] = row
        j += 1

# %%
df_mtk = pd.DataFrame(columns=['證券代碼','年月日','開盤價(元)','收盤價(元)'])
j = 0
for index, row in df_2018.iterrows():
    if row['證券代碼'] == '2454 聯發科':
        df_mtk.loc[j] = row
        j += 1
for index, row in df_2017.iterrows():
    if row['證券代碼'] == '2454 聯發科':
        df_mtk.loc[j] = row
        j += 1
for index, row in df_2016.iterrows():
    if row['證券代碼'] == '2454 聯發科':
        df_mtk.loc[j] = row
        j += 1

# %%
df_cht = pd.DataFrame(columns=['證券代碼','年月日','開盤價(元)','收盤價(元)'])
j = 0
for index, row in df_2018.iterrows():
    if row['證券代碼'] == '2412 中華電':
        df_cht.loc[j] = row
        j += 1
for index, row in df_2017.iterrows():
    if row['證券代碼'] == '2412 中華電':
        df_cht.loc[j] = row
        j += 1
for index, row in df_2016.iterrows():
    if row['證券代碼'] == '2412 中華電':
        df_cht.loc[j] = row
        j += 1

# %%
df_ctbc = pd.DataFrame(columns=['證券代碼','年月日','開盤價(元)','收盤價(元)'])
j = 0
for index, row in df_2018.iterrows():
    if row['證券代碼'] == '2891 中信金':
        df_ctbc.loc[j] = row
        j += 1
for index, row in df_2017.iterrows():
    if row['證券代碼'] == '2891 中信金':
        df_ctbc.loc[j] = row
        j += 1
for index, row in df_2016.iterrows():
    if row['證券代碼'] == '2891 中信金':
        df_ctbc.loc[j] = row
        j += 1

# %%
df_fcfc = pd.DataFrame(columns=['證券代碼','年月日','開盤價(元)','收盤價(元)'])
j = 0
for index, row in df_2018.iterrows():
    if row['證券代碼'] == '1326 台化':
        df_fcfc.loc[j] = row
        j += 1
for index, row in df_2017.iterrows():
    if row['證券代碼'] == '1326 台化':
        df_fcfc.loc[j] = row
        j += 1
for index, row in df_2016.iterrows():
    if row['證券代碼'] == '1326 台化':
        df_fcfc.loc[j] = row
        j += 1

# %%
df_uni = pd.DataFrame(columns=['證券代碼','年月日','開盤價(元)','收盤價(元)'])
j = 0
for index, row in df_2018.iterrows():
    if row['證券代碼'] == '1216 統一':
        df_uni.loc[j] = row
        j += 1
for index, row in df_2017.iterrows():
    if row['證券代碼'] == '1216 統一':
        df_uni.loc[j] = row
        j += 1
for index, row in df_2016.iterrows():
    if row['證券代碼'] == '1216 統一':
        df_uni.loc[j] = row
        j += 1

# %%
df_cathay = pd.DataFrame(columns=['證券代碼','年月日','開盤價(元)','收盤價(元)'])
j = 0
for index, row in df_2018.iterrows():
    if row['證券代碼'] == '2882 國泰金':
        df_cathay.loc[j] = row
        j += 1
for index, row in df_2017.iterrows():
    if row['證券代碼'] == '2882 國泰金':
        df_cathay.loc[j] = row
        j += 1
for index, row in df_2016.iterrows():
    if row['證券代碼'] == '2882 國泰金':
        df_cathay.loc[j] = row
        j += 1

# %%
df_npc = pd.DataFrame(columns=['證券代碼','年月日','開盤價(元)','收盤價(元)'])
j = 0
for index, row in df_2018.iterrows():
    if row['證券代碼'] == '1303 南亞':
        df_npc.loc[j] = row
        j += 1
for index, row in df_2017.iterrows():
    if row['證券代碼'] == '1303 南亞':
        df_npc.loc[j] = row
        j += 1
for index, row in df_2016.iterrows():
    if row['證券代碼'] == '1303 南亞':
        df_npc.loc[j] = row
        j += 1

# %%
tsmc_up_date = list()
tsmc_down_date = list()
tsmc_flat_date = list()

# 定義上漲/下跌的幅度 = 1.5%
benchmark = 0.015

for index, row in df_tsmc.iterrows():
    delta = (float(row['收盤價(元)']) - float(row['開盤價(元)'])) / float(row['開盤價(元)'])
    date = row['年月日'].date()
    if delta >= benchmark:
        tsmc_up_date.append(date)
    elif delta <= -1 * benchmark:
        tsmc_down_date.append(date)
    else:
        tsmc_flat_date.append(date)

# %%
foxconn_up_date = list()
foxconn_down_date = list()
foxconn_flat_date = list()

# 定義上漲/下跌的幅度 = 1.5%
benchmark = 0.015

for index, row in df_foxconn.iterrows():
    delta = (float(row['收盤價(元)']) - float(row['開盤價(元)'])) / float(row['開盤價(元)'])
    date = row['年月日'].date()
    if delta >= benchmark:
        foxconn_up_date.append(date)
    elif delta <= -1 * benchmark:
        foxconn_down_date.append(date)
    else:
        foxconn_flat_date.append(date)

# %%
fpc_up_date = list()
fpc_down_date = list()
fpc_flat_date = list()

# 定義上漲/下跌的幅度 = 1.5%
benchmark = 0.015

for index, row in df_fpc.iterrows():
    delta = (float(row['收盤價(元)']) - float(row['開盤價(元)'])) / float(row['開盤價(元)'])
    date = row['年月日'].date()
    if delta >= benchmark:
        fpc_up_date.append(date)
    elif delta <= -1 * benchmark:
        fpc_down_date.append(date)
    else:
        fpc_flat_date.append(date)

# %%
largan_up_date = list()
largan_down_date = list()
largan_flat_date = list()

# 定義上漲/下跌的幅度 = 1.5%
benchmark = 0.015

for index, row in df_largan.iterrows():
    delta = (float(row['收盤價(元)']) - float(row['開盤價(元)'])) / float(row['開盤價(元)'])
    date = row['年月日'].date()
    if delta >= benchmark:
        largan_up_date.append(date)
    elif delta <= -1 * benchmark:
        largan_down_date.append(date)
    else:
        largan_flat_date.append(date)

# %%
mtk_up_date = list()
mtk_down_date = list()
mtk_flat_date = list()

# 定義上漲/下跌的幅度 = 1.5%
benchmark = 0.015

for index, row in df_mtk.iterrows():
    delta = (float(row['收盤價(元)']) - float(row['開盤價(元)'])) / float(row['開盤價(元)'])
    date = row['年月日'].date()
    if delta >= benchmark:
        mtk_up_date.append(date)
    elif delta <= -1 * benchmark:
        mtk_down_date.append(date)
    else:
        mtk_flat_date.append(date)

# %%
cht_up_date = list()
cht_down_date = list()
cht_flat_date = list()

# 定義上漲/下跌的幅度 = 1.5%
benchmark = 0.015

for index, row in df_cht.iterrows():
    delta = (float(row['收盤價(元)']) - float(row['開盤價(元)'])) / float(row['開盤價(元)'])
    date = row['年月日'].date()
    if delta >= benchmark:
        cht_up_date.append(date)
    elif delta <= -1 * benchmark:
        cht_down_date.append(date)
    else:
        cht_flat_date.append(date)

# %%
ctbc_up_date = list()
ctbc_down_date = list()
ctbc_flat_date = list()

# 定義上漲/下跌的幅度 = 1.5%
benchmark = 0.015

for index, row in df_ctbc.iterrows():
    delta = (float(row['收盤價(元)']) - float(row['開盤價(元)'])) / float(row['開盤價(元)'])
    date = row['年月日'].date()
    if delta >= benchmark:
        ctbc_up_date.append(date)
    elif delta <= -1 * benchmark:
        ctbc_down_date.append(date)
    else:
        ctbc_flat_date.append(date)

# %%
fcfc_up_date = list()
fcfc_down_date = list()
fcfc_flat_date = list()

# 定義上漲/下跌的幅度 = 1.5%
benchmark = 0.015

for index, row in df_fcfc.iterrows():
    delta = (float(row['收盤價(元)']) - float(row['開盤價(元)'])) / float(row['開盤價(元)'])
    date = row['年月日'].date()
    if delta >= benchmark:
        fcfc_up_date.append(date)
    elif delta <= -1 * benchmark:
        fcfc_down_date.append(date)
    else:
        fcfc_flat_date.append(date)

# %%
uni_up_date = list()
uni_down_date = list()
uni_flat_date = list()

# 定義上漲/下跌的幅度 = 1.5%
benchmark = 0.015

for index, row in df_uni.iterrows():
    delta = (float(row['收盤價(元)']) - float(row['開盤價(元)'])) / float(row['開盤價(元)'])
    date = row['年月日'].date()
    if delta >= benchmark:
        uni_up_date.append(date)
    elif delta <= -1 * benchmark:
        uni_down_date.append(date)
    else:
        uni_flat_date.append(date)

# %%
cathay_up_date = list()
cathay_down_date = list()
cathay_flat_date = list()

# 定義上漲/下跌的幅度 = 1.5%
benchmark = 0.015

for index, row in df_cathay.iterrows():
    delta = (float(row['收盤價(元)']) - float(row['開盤價(元)'])) / float(row['開盤價(元)'])
    date = row['年月日'].date()
    if delta >= benchmark:
        cathay_up_date.append(date)
    elif delta <= -1 * benchmark:
        cathay_down_date.append(date)
    else:
        cathay_flat_date.append(date)

# %%
npc_up_date = list()
npc_down_date = list()
npc_flat_date = list()

# 定義上漲/下跌的幅度 = 1.5%
benchmark = 0.015

for index, row in df_npc.iterrows():
    delta = (float(row['收盤價(元)']) - float(row['開盤價(元)'])) / float(row['開盤價(元)'])
    date = row['年月日'].date()
    if delta >= benchmark:
        npc_up_date.append(date)
    elif delta <= -1 * benchmark:
        npc_down_date.append(date)
    else:
        npc_flat_date.append(date)

# %%
cathay_up_date
# Out:
# [datetime.date(2018, 12, 4),
#  datetime.date(2018, 11, 13),
#  datetime.date(2018, 10, 12),
#  datetime.date(2018, 7, 31),
#  datetime.date(2018, 7, 12),
#  datetime.date(2018, 6, 29),
#  datetime.date(2018, 6, 15),
#  datetime.date(2018, 5, 11),
#  datetime.date(2018, 4, 19),
#  datetime.date(2018, 3, 12),
#  datetime.date(2017, 12, 27),
#  datetime.date(2017, 12, 19),
#  datetime.date(2017, 12, 1),
#  datetime.date(2017, 11, 21),
#  datetime.date(2017, 9, 21),
#  datetime.date(2017, 9, 8),
#  datetime.date(2017, 6, 26),
#  datetime.date(2017, 4, 25),
#  datetime.date(2017, 3, 8),
#  datetime.date(2017, 2, 6),
#  datetime.date(2016, 12, 28),
#  datetime.date(2016, 12, 26),
#  datetime.date(2016, 12, 15),
#  datetime.date(2016, 12, 1),
#  datetime.date(2016, 11, 25),
#  datetime.date(2016, 11, 14),
#  datetime.date(2016, 11, 10),
#  datetime.date(2016, 10, 18),
#  datetime.date(2016, 10, 12),
#  datetime.date(2016, 9, 21),
#  datetime.date(2016, 9, 19),
# ...

# %%
df_tsmc_news = pd.DataFrame(pd.read_excel("company_news(2016~2018).xlsx", sheet_name = "TSMC"))
df_foxconn_news = pd.DataFrame(pd.read_excel("company_news(2016~2018).xlsx", sheet_name = "Foxconn"))
df_fpc_news = pd.DataFrame(pd.read_excel("company_news(2016~2018).xlsx", sheet_name = "FPC"))
df_largan_news = pd.DataFrame(pd.read_excel("company_news(2016~2018).xlsx", sheet_name = "大立光"))
df_mtk_news = pd.DataFrame(pd.read_excel("company_news(2016~2018).xlsx", sheet_name = "聯發科"))
df_cht_news = pd.DataFrame(pd.read_excel("company_news(2016~2018).xlsx", sheet_name = "中華電"))
df_ctbc_news = pd.DataFrame(pd.read_excel("company_news(2016~2018).xlsx", sheet_name = "中信金"))
df_fcfc_news = pd.DataFrame(pd.read_excel("company_news(2016~2018).xlsx", sheet_name = "台化"))
df_uni_news = pd.DataFrame(pd.read_excel("company_news(2016~2018).xlsx", sheet_name = "統一"))
df_cathay_news = pd.DataFrame(pd.read_excel("company_news(2016~2018).xlsx", sheet_name = "國泰金"))
df_npc_news = pd.DataFrame(pd.read_excel("company_news(2016~2018).xlsx", sheet_name = "南亞"))

# %%
df_tsmc_news
# Out:
#                         id            post_time  \
# 0        1451611607275_N01    2016/1/1 09:05:00
# 1        1451613407274_N01    2016/1/1 09:27:00
# 2        1451621511658_N01    2016/1/1 11:46:00
# 3        1451621512925_N01    2016/1/1 11:52:00
# 4        1451623307179_N01    2016/1/1 12:18:00
# 5        1451706107903_N01    2016/1/2 11:12:00
# 6        1451783511311_N01    2016/1/3 08:59:00
# 7        1451795207752_N01    2016/1/3 12:03:00
# 8        1451864508513_N01    2016/1/4 07:24:00
# 9        1451865407565_N01    2016/1/4 07:34:00
# 10       1451867210012_N01    2016/1/4 07:56:00
# 11       1451867211260_N01    2016/1/4 07:56:00
# 12       1451867221333_N01    2016/1/4 08:00:00
# 13       1451867226195_N01    2016/1/4 08:01:00
# 14       1451869007598_N01    2016/1/4 08:29:00
# 15       1451879808470_N01    2016/1/4 11:34:00
# 16       1451887907638_N01    2016/1/4 13:44:00
# 17       1451892413661_N01    2016/1/4 15:09:00
# ...

# %%
df_tsmc_up_news = pd.DataFrame(columns=['id','post_time','title','content'])
df_tsmc_down_news = pd.DataFrame(columns=['id','post_time','title','content'])
up_index = 0
down_index = 0
for index, row in df_tsmc_news.iterrows():
    tmp = row['post_time'].split(' ')
    tmp_date = tmp[0].split('/')
    date = datetime.date(int(tmp_date[0]), int(tmp_date[1]), int(tmp_date[2]))
    
    
    for i in range(len(tsmc_up_date)):
        if tsmc_up_date[i].weekday() == 0:
            if ((tsmc_up_date[i] - timedelta(days=3)) == date) and tmp[1] > "13:30:00":
                df_tsmc_up_news.loc[up_index] = row
                up_index += 1
            elif((tsmc_up_date[i] - timedelta(days=2)) == date or (tsmc_up_date[i] - timedelta(days=2)) == date):
                df_tsmc_up_news.loc[up_index] = row
                up_index += 1
            elif ((tsmc_up_date[i]) == date) and tmp[1] < "13:30:00":
                df_tsmc_up_news.loc[up_index] = row
                up_index += 1
        else:
            if ((tsmc_up_date[i] - timedelta(days=1)) == date) and tmp[1] > "13:30:00":
                df_tsmc_up_news.loc[up_index] = row
                up_index += 1
            elif ((tsmc_up_date[i]) == date) and tmp[1] < "13:30:00":
                df_tsmc_up_news.loc[up_index] = row
                up_index += 1
    
    j = 0
    for i in range(len(tsmc_down_date)):       
        if tsmc_down_date[i].weekday() == 0:
            if ((tsmc_down_date[i] - timedelta(days=3)) == date) and tmp[1] > "13:30:00":
                df_tsmc_down_news.loc[down_index] = row
                down_index += 1
            elif((tsmc_down_date[i] - timedelta(days=2)) == date or (tsmc_down_date[i] - timedelta(days=2)) == date):
                df_tsmc_down_news.loc[down_index] = row
                down_index += 1
            elif ((tsmc_down_date[i]) == date) and tmp[1] < "13:30:00":
                df_tsmc_down_news.loc[down_index] = row
                down_index += 1
        else:
            if ((tsmc_down_date[i] - timedelta(days=1)) == date) and tmp[1] > "13:30:00":
                df_tsmc_down_news.loc[down_index] = row
                down_index += 1
            elif ((tsmc_down_date[i]) == date) and tmp[1] < "13:30:00":
                df_tsmc_down_news.loc[down_index] = row
                down_index += 1

# %%
df_foxconn_up_news = pd.DataFrame(columns=['id','post_time','title','content'])
df_foxconn_down_news = pd.DataFrame(columns=['id','post_time','title','content'])
up_index = 0
down_index = 0
for index, row in df_foxconn_news.iterrows():
    tmp = row['post_time'].split(' ')
    tmp_date = tmp[0].split('/')
    date = datetime.date(int(tmp_date[0]), int(tmp_date[1]), int(tmp_date[2]))
    
    
    for i in range(len(foxconn_up_date)):
        if foxconn_up_date[i].weekday() == 0:
            if ((foxconn_up_date[i] - timedelta(days=3)) == date) and tmp[1] > "13:30:00":
                df_foxconn_up_news.loc[up_index] = row
                up_index += 1
            elif((foxconn_up_date[i] - timedelta(days=2)) == date or (foxconn_up_date[i] - timedelta(days=2)) == date):
                df_foxconn_up_news.loc[up_index] = row
                up_index += 1
            elif ((foxconn_up_date[i]) == date) and tmp[1] < "13:30:00":
                df_foxconn_up_news.loc[up_index] = row
                up_index += 1
        else:
            if ((foxconn_up_date[i] - timedelta(days=1)) == date) and tmp[1] > "13:30:00":
                df_foxconn_up_news.loc[up_index] = row
                up_index += 1
            elif ((foxconn_up_date[i]) == date) and tmp[1] < "13:30:00":
                df_foxconn_up_news.loc[up_index] = row
                up_index += 1
    
    j = 0
    for i in range(len(foxconn_down_date)):       
        if foxconn_down_date[i].weekday() == 0:
            if ((foxconn_down_date[i] - timedelta(days=3)) == date) and tmp[1] > "13:30:00":
                df_foxconn_down_news.loc[down_index] = row
                down_index += 1
            elif((foxconn_down_date[i] - timedelta(days=2)) == date or (foxconn_down_date[i] - timedelta(days=2)) == date):
                df_foxconn_down_news.loc[down_index] = row
                down_index += 1
            elif ((foxconn_down_date[i]) == date) and tmp[1] < "13:30:00":
                df_foxconn_down_news.loc[down_index] = row
                down_index += 1
        else:
            if ((foxconn_down_date[i] - timedelta(days=1)) == date) and tmp[1] > "13:30:00":
                df_foxconn_down_news.loc[down_index] = row
                down_index += 1
            elif ((foxconn_down_date[i]) == date) and tmp[1] < "13:30:00":
                df_foxconn_down_news.loc[down_index] = row
                down_index += 1

# %%
df_fpc_up_news = pd.DataFrame(columns=['id','post_time','title','content'])
df_fpc_down_news = pd.DataFrame(columns=['id','post_time','title','content'])
up_index = 0
down_index = 0
for index, row in df_fpc_news.iterrows():
    tmp = row['post_time'].split(' ')
    tmp_date = tmp[0].split('/')
    date = datetime.date(int(tmp_date[0]), int(tmp_date[1]), int(tmp_date[2]))
    
    
    for i in range(len(fpc_up_date)):
        if fpc_up_date[i].weekday() == 0:
            if ((fpc_up_date[i] - timedelta(days=3)) == date) and tmp[1] > "13:30:00":
                df_fpc_up_news.loc[up_index] = row
                up_index += 1
            elif((fpc_up_date[i] - timedelta(days=2)) == date or (fpc_up_date[i] - timedelta(days=2)) == date):
                df_fpc_up_news.loc[up_index] = row
                up_index += 1
            elif ((fpc_up_date[i]) == date) and tmp[1] < "13:30:00":
                df_fpc_up_news.loc[up_index] = row
                up_index += 1
        else:
            if ((fpc_up_date[i] - timedelta(days=1)) == date) and tmp[1] > "13:30:00":
                df_fpc_up_news.loc[up_index] = row
                up_index += 1
            elif ((fpc_up_date[i]) == date) and tmp[1] < "13:30:00":
                df_fpc_up_news.loc[up_index] = row
                up_index += 1
    
    j = 0
    for i in range(len(fpc_down_date)):       
        if fpc_down_date[i].weekday() == 0:
            if ((fpc_down_date[i] - timedelta(days=3)) == date) and tmp[1] > "13:30:00":
                df_fpc_down_news.loc[down_index] = row
                down_index += 1
            elif((fpc_down_date[i] - timedelta(days=2)) == date or (fpc_down_date[i] - timedelta(days=2)) == date):
                df_fpc_down_news.loc[down_index] = row
                down_index += 1
            elif ((fpc_down_date[i]) == date) and tmp[1] < "13:30:00":
                df_fpc_down_news.loc[down_index] = row
                down_index += 1
        else:
            if ((fpc_down_date[i] - timedelta(days=1)) == date) and tmp[1] > "13:30:00":
                df_fpc_down_news.loc[down_index] = row
                down_index += 1
            elif ((fpc_down_date[i]) == date) and tmp[1] < "13:30:00":
                df_fpc_down_news.loc[down_index] = row
                down_index += 1

# %%
df_largan_up_news = pd.DataFrame(columns=['id','post_time','title','content'])
df_largan_down_news = pd.DataFrame(columns=['id','post_time','title','content'])
up_index = 0
down_index = 0
for index, row in df_largan_news.iterrows():
    tmp = row['post_time'].split(' ')
    tmp_date = tmp[0].split('/')
    date = datetime.date(int(tmp_date[0]), int(tmp_date[1]), int(tmp_date[2]))
    
    
    for i in range(len(largan_up_date)):
        if largan_up_date[i].weekday() == 0:
            if ((largan_up_date[i] - timedelta(days=3)) == date) and tmp[1] > "13:30:00":
                df_largan_up_news.loc[up_index] = row
                up_index += 1
            elif((largan_up_date[i] - timedelta(days=2)) == date or (largan_up_date[i] - timedelta(days=2)) == date):
                df_largan_up_news.loc[up_index] = row
                up_index += 1
            elif ((largan_up_date[i]) == date) and tmp[1] < "13:30:00":
                df_largan_up_news.loc[up_index] = row
                up_index += 1
        else:
            if ((largan_up_date[i] - timedelta(days=1)) == date) and tmp[1] > "13:30:00":
                df_largan_up_news.loc[up_index] = row
                up_index += 1
            elif ((largan_up_date[i]) == date) and tmp[1] < "13:30:00":
                df_largan_up_news.loc[up_index] = row
                up_index += 1
    
    j = 0
    for i in range(len(largan_down_date)):       
        if largan_down_date[i].weekday() == 0:
            if ((largan_down_date[i] - timedelta(days=3)) == date) and tmp[1] > "13:30:00":
                df_largan_down_news.loc[down_index] = row
                down_index += 1
            elif((largan_down_date[i] - timedelta(days=2)) == date or (largan_down_date[i] - timedelta(days=2)) == date):
                df_largan_down_news.loc[down_index] = row
                down_index += 1
            elif ((largan_down_date[i]) == date) and tmp[1] < "13:30:00":
                df_largan_down_news.loc[down_index] = row
                down_index += 1
        else:
            if ((largan_down_date[i] - timedelta(days=1)) == date) and tmp[1] > "13:30:00":
                df_largan_down_news.loc[down_index] = row
                down_index += 1
            elif ((largan_down_date[i]) == date) and tmp[1] < "13:30:00":
                df_largan_down_news.loc[down_index] = row
                down_index += 1

# %%
df_mtk_up_news = pd.DataFrame(columns=['id','post_time','title','content'])
df_mtk_down_news = pd.DataFrame(columns=['id','post_time','title','content'])
up_index = 0
down_index = 0
for index, row in df_mtk_news.iterrows():
    tmp = row['post_time'].split(' ')
    tmp_date = tmp[0].split('/')
    date = datetime.date(int(tmp_date[0]), int(tmp_date[1]), int(tmp_date[2]))
    
    
    for i in range(len(mtk_up_date)):
        if mtk_up_date[i].weekday() == 0:
            if ((mtk_up_date[i] - timedelta(days=3)) == date) and tmp[1] > "13:30:00":
                df_mtk_up_news.loc[up_index] = row
                up_index += 1
            elif((mtk_up_date[i] - timedelta(days=2)) == date or (mtk_up_date[i] - timedelta(days=2)) == date):
                df_mtk_up_news.loc[up_index] = row
                up_index += 1
            elif ((mtk_up_date[i]) == date) and tmp[1] < "13:30:00":
                df_mtk_up_news.loc[up_index] = row
                up_index += 1
        else:
            if ((mtk_up_date[i] - timedelta(days=1)) == date) and tmp[1] > "13:30:00":
                df_mtk_up_news.loc[up_index] = row
                up_index += 1
            elif ((mtk_up_date[i]) == date) and tmp[1] < "13:30:00":
                df_mtk_up_news.loc[up_index] = row
                up_index += 1
    
    j = 0
    for i in range(len(mtk_down_date)):       
        if mtk_down_date[i].weekday() == 0:
            if ((mtk_down_date[i] - timedelta(days=3)) == date) and tmp[1] > "13:30:00":
                df_mtk_down_news.loc[down_index] = row
                down_index += 1
            elif((mtk_down_date[i] - timedelta(days=2)) == date or (mtk_down_date[i] - timedelta(days=2)) == date):
                df_mtk_down_news.loc[down_index] = row
                down_index += 1
            elif ((mtk_down_date[i]) == date) and tmp[1] < "13:30:00":
                df_mtk_down_news.loc[down_index] = row
                down_index += 1
        else:
            if ((mtk_down_date[i] - timedelta(days=1)) == date) and tmp[1] > "13:30:00":
                df_mtk_down_news.loc[down_index] = row
                down_index += 1
            elif ((mtk_down_date[i]) == date) and tmp[1] < "13:30:00":
                df_mtk_down_news.loc[down_index] = row
                down_index += 1

# %%
df_cht_up_news = pd.DataFrame(columns=['id','post_time','title','content'])
df_cht_down_news = pd.DataFrame(columns=['id','post_time','title','content'])
up_index = 0
down_index = 0
for index, row in df_cht_news.iterrows():
    tmp = row['post_time'].split(' ')
    tmp_date = tmp[0].split('/')
    date = datetime.date(int(tmp_date[0]), int(tmp_date[1]), int(tmp_date[2]))
    
    
    for i in range(len(cht_up_date)):
        if cht_up_date[i].weekday() == 0:
            if ((cht_up_date[i] - timedelta(days=3)) == date) and tmp[1] > "13:30:00":
                df_cht_up_news.loc[up_index] = row
                up_index += 1
            elif((cht_up_date[i] - timedelta(days=2)) == date or (cht_up_date[i] - timedelta(days=2)) == date):
                df_cht_up_news.loc[up_index] = row
                up_index += 1
            elif ((cht_up_date[i]) == date) and tmp[1] < "13:30:00":
                df_cht_up_news.loc[up_index] = row
                up_index += 1
        else:
            if ((cht_up_date[i] - timedelta(days=1)) == date) and tmp[1] > "13:30:00":
                df_cht_up_news.loc[up_index] = row
                up_index += 1
            elif ((cht_up_date[i]) == date) and tmp[1] < "13:30:00":
                df_cht_up_news.loc[up_index] = row
                up_index += 1
    
    j = 0
    for i in range(len(cht_down_date)):       
        if cht_down_date[i].weekday() == 0:
            if ((cht_down_date[i] - timedelta(days=3)) == date) and tmp[1] > "13:30:00":
                df_cht_down_news.loc[down_index] = row
                down_index += 1
            elif((cht_down_date[i] - timedelta(days=2)) == date or (cht_down_date[i] - timedelta(days=2)) == date):
                df_cht_down_news.loc[down_index] = row
                down_index += 1
            elif ((cht_down_date[i]) == date) and tmp[1] < "13:30:00":
                df_cht_down_news.loc[down_index] = row
                down_index += 1
        else:
            if ((cht_down_date[i] - timedelta(days=1)) == date) and tmp[1] > "13:30:00":
                df_cht_down_news.loc[down_index] = row
                down_index += 1
            elif ((cht_down_date[i]) == date) and tmp[1] < "13:30:00":
                df_cht_down_news.loc[down_index] = row
                down_index += 1

# %%
df_ctbc_up_news = pd.DataFrame(columns=['id','post_time','title','content'])
df_ctbc_down_news = pd.DataFrame(columns=['id','post_time','title','content'])
up_index = 0
down_index = 0
for index, row in df_ctbc_news.iterrows():
    tmp = row['post_time'].split(' ')
    tmp_date = tmp[0].split('/')
    date = datetime.date(int(tmp_date[0]), int(tmp_date[1]), int(tmp_date[2]))
    
    
    for i in range(len(ctbc_up_date)):
        if ctbc_up_date[i].weekday() == 0:
            if ((ctbc_up_date[i] - timedelta(days=3)) == date) and tmp[1] > "13:30:00":
                df_ctbc_up_news.loc[up_index] = row
                up_index += 1
            elif((ctbc_up_date[i] - timedelta(days=2)) == date or (ctbc_up_date[i] - timedelta(days=2)) == date):
                df_ctbc_up_news.loc[up_index] = row
                up_index += 1
            elif ((ctbc_up_date[i]) == date) and tmp[1] < "13:30:00":
                df_ctbc_up_news.loc[up_index] = row
                up_index += 1
        else:
            if ((ctbc_up_date[i] - timedelta(days=1)) == date) and tmp[1] > "13:30:00":
                df_ctbc_up_news.loc[up_index] = row
                up_index += 1
            elif ((ctbc_up_date[i]) == date) and tmp[1] < "13:30:00":
                df_ctbc_up_news.loc[up_index] = row
                up_index += 1
    
    j = 0
    for i in range(len(ctbc_down_date)):       
        if ctbc_down_date[i].weekday() == 0:
            if ((ctbc_down_date[i] - timedelta(days=3)) == date) and tmp[1] > "13:30:00":
                df_ctbc_down_news.loc[down_index] = row
                down_index += 1
            elif((ctbc_down_date[i] - timedelta(days=2)) == date or (ctbc_down_date[i] - timedelta(days=2)) == date):
                df_ctbc_down_news.loc[down_index] = row
                down_index += 1
            elif ((ctbc_down_date[i]) == date) and tmp[1] < "13:30:00":
                df_ctbc_down_news.loc[down_index] = row
                down_index += 1
        else:
            if ((ctbc_down_date[i] - timedelta(days=1)) == date) and tmp[1] > "13:30:00":
                df_ctbc_down_news.loc[down_index] = row
                down_index += 1
            elif ((ctbc_down_date[i]) == date) and tmp[1] < "13:30:00":
                df_ctbc_down_news.loc[down_index] = row
                down_index += 1

# %%
df_fcfc_up_news = pd.DataFrame(columns=['id','post_time','title','content'])
df_fcfc_down_news = pd.DataFrame(columns=['id','post_time','title','content'])
up_index = 0
down_index = 0
for index, row in df_fcfc_news.iterrows():
    tmp = row['post_time'].split(' ')
    tmp_date = tmp[0].split('/')
    date = datetime.date(int(tmp_date[0]), int(tmp_date[1]), int(tmp_date[2]))
    
    
    for i in range(len(fcfc_up_date)):
        if fcfc_up_date[i].weekday() == 0:
            if ((fcfc_up_date[i] - timedelta(days=3)) == date) and tmp[1] > "13:30:00":
                df_fcfc_up_news.loc[up_index] = row
                up_index += 1
            elif((fcfc_up_date[i] - timedelta(days=2)) == date or (fcfc_up_date[i] - timedelta(days=2)) == date):
                df_fcfc_up_news.loc[up_index] = row
                up_index += 1
            elif ((fcfc_up_date[i]) == date) and tmp[1] < "13:30:00":
                df_fcfc_up_news.loc[up_index] = row
                up_index += 1
        else:
            if ((fcfc_up_date[i] - timedelta(days=1)) == date) and tmp[1] > "13:30:00":
                df_fcfc_up_news.loc[up_index] = row
                up_index += 1
            elif ((fcfc_up_date[i]) == date) and tmp[1] < "13:30:00":
                df_fcfc_up_news.loc[up_index] = row
                up_index += 1
    
    j = 0
    for i in range(len(fcfc_down_date)):       
        if fcfc_down_date[i].weekday() == 0:
            if ((fcfc_down_date[i] - timedelta(days=3)) == date) and tmp[1] > "13:30:00":
                df_fcfc_down_news.loc[down_index] = row
                down_index += 1
            elif((fcfc_down_date[i] - timedelta(days=2)) == date or (fcfc_down_date[i] - timedelta(days=2)) == date):
                df_fcfc_down_news.loc[down_index] = row
                down_index += 1
            elif ((fcfc_down_date[i]) == date) and tmp[1] < "13:30:00":
                df_fcfc_down_news.loc[down_index] = row
                down_index += 1
        else:
            if ((fcfc_down_date[i] - timedelta(days=1)) == date) and tmp[1] > "13:30:00":
                df_fcfc_down_news.loc[down_index] = row
                down_index += 1
            elif ((fcfc_down_date[i]) == date) and tmp[1] < "13:30:00":
                df_fcfc_down_news.loc[down_index] = row
                down_index += 1

# %%
df_uni_up_news = pd.DataFrame(columns=['id','post_time','title','content'])
df_uni_down_news = pd.DataFrame(columns=['id','post_time','title','content'])
up_index = 0
down_index = 0
for index, row in df_uni_news.iterrows():
    tmp = row['post_time'].split(' ')
    tmp_date = tmp[0].split('/')
    date = datetime.date(int(tmp_date[0]), int(tmp_date[1]), int(tmp_date[2]))
    
    
    for i in range(len(uni_up_date)):
        if uni_up_date[i].weekday() == 0:
            if ((uni_up_date[i] - timedelta(days=3)) == date) and tmp[1] > "13:30:00":
                df_uni_up_news.loc[up_index] = row
                up_index += 1
            elif((uni_up_date[i] - timedelta(days=2)) == date or (uni_up_date[i] - timedelta(days=2)) == date):
                df_uni_up_news.loc[up_index] = row
                up_index += 1
            elif ((uni_up_date[i]) == date) and tmp[1] < "13:30:00":
                df_uni_up_news.loc[up_index] = row
                up_index += 1
        else:
            if ((uni_up_date[i] - timedelta(days=1)) == date) and tmp[1] > "13:30:00":
                df_uni_up_news.loc[up_index] = row
                up_index += 1
            elif ((uni_up_date[i]) == date) and tmp[1] < "13:30:00":
                df_uni_up_news.loc[up_index] = row
                up_index += 1
    
    j = 0
    for i in range(len(uni_down_date)):       
        if uni_down_date[i].weekday() == 0:
            if ((uni_down_date[i] - timedelta(days=3)) == date) and tmp[1] > "13:30:00":
                df_uni_down_news.loc[down_index] = row
                down_index += 1
            elif((uni_down_date[i] - timedelta(days=2)) == date or (uni_down_date[i] - timedelta(days=2)) == date):
                df_uni_down_news.loc[down_index] = row
                down_index += 1
            elif ((uni_down_date[i]) == date) and tmp[1] < "13:30:00":
                df_uni_down_news.loc[down_index] = row
                down_index += 1
        else:
            if ((uni_down_date[i] - timedelta(days=1)) == date) and tmp[1] > "13:30:00":
                df_uni_down_news.loc[down_index] = row
                down_index += 1
            elif ((uni_down_date[i]) == date) and tmp[1] < "13:30:00":
                df_uni_down_news.loc[down_index] = row
                down_index += 1

# %%
df_cathay_up_news = pd.DataFrame(columns=['id','post_time','title','content'])
df_cathay_down_news = pd.DataFrame(columns=['id','post_time','title','content'])
up_index = 0
down_index = 0
for index, row in df_cathay_news.iterrows():
    tmp = row['post_time'].split(' ')
    tmp_date = tmp[0].split('/')
    date = datetime.date(int(tmp_date[0]), int(tmp_date[1]), int(tmp_date[2]))
    
    
    for i in range(len(cathay_up_date)):
        if cathay_up_date[i].weekday() == 0:
            if ((cathay_up_date[i] - timedelta(days=3)) == date) and tmp[1] > "13:30:00":
                df_cathay_up_news.loc[up_index] = row
                up_index += 1
            elif((cathay_up_date[i] - timedelta(days=2)) == date or (cathay_up_date[i] - timedelta(days=2)) == date):
                df_cathay_up_news.loc[up_index] = row
                up_index += 1
            elif ((cathay_up_date[i]) == date) and tmp[1] < "13:30:00":
                df_cathay_up_news.loc[up_index] = row
                up_index += 1
        else:
            if ((cathay_up_date[i] - timedelta(days=1)) == date) and tmp[1] > "13:30:00":
                df_cathay_up_news.loc[up_index] = row
                up_index += 1
            elif ((cathay_up_date[i]) == date) and tmp[1] < "13:30:00":
                df_cathay_up_news.loc[up_index] = row
                up_index += 1
    
    j = 0
    for i in range(len(cathay_down_date)):       
        if cathay_down_date[i].weekday() == 0:
            if ((cathay_down_date[i] - timedelta(days=3)) == date) and tmp[1] > "13:30:00":
                df_cathay_down_news.loc[down_index] = row
                down_index += 1
            elif((cathay_down_date[i] - timedelta(days=2)) == date or (cathay_down_date[i] - timedelta(days=2)) == date):
                df_cathay_down_news.loc[down_index] = row
                down_index += 1
            elif ((cathay_down_date[i]) == date) and tmp[1] < "13:30:00":
                df_cathay_down_news.loc[down_index] = row
                down_index += 1
        else:
            if ((cathay_down_date[i] - timedelta(days=1)) == date) and tmp[1] > "13:30:00":
                df_cathay_down_news.loc[down_index] = row
                down_index += 1
            elif ((cathay_down_date[i]) == date) and tmp[1] < "13:30:00":
                df_cathay_down_news.loc[down_index] = row
                down_index += 1

# %%
df_npc_up_news = pd.DataFrame(columns=['id','post_time','title','content'])
df_npc_down_news = pd.DataFrame(columns=['id','post_time','title','content'])
up_index = 0
down_index = 0
for index, row in df_npc_news.iterrows():
    tmp = row['post_time'].split(' ')
    tmp_date = tmp[0].split('/')
    date = datetime.date(int(tmp_date[0]), int(tmp_date[1]), int(tmp_date[2]))
    
    
    for i in range(len(npc_up_date)):
        if npc_up_date[i].weekday() == 0:
            if ((npc_up_date[i] - timedelta(days=3)) == date) and tmp[1] > "13:30:00":
                df_npc_up_news.loc[up_index] = row
                up_index += 1
            elif((npc_up_date[i] - timedelta(days=2)) == date or (npc_up_date[i] - timedelta(days=2)) == date):
                df_npc_up_news.loc[up_index] = row
                up_index += 1
            elif ((npc_up_date[i]) == date) and tmp[1] < "13:30:00":
                df_npc_up_news.loc[up_index] = row
                up_index += 1
        else:
            if ((npc_up_date[i] - timedelta(days=1)) == date) and tmp[1] > "13:30:00":
                df_npc_up_news.loc[up_index] = row
                up_index += 1
            elif ((npc_up_date[i]) == date) and tmp[1] < "13:30:00":
                df_npc_up_news.loc[up_index] = row
                up_index += 1
    
    j = 0
    for i in range(len(npc_down_date)):       
        if npc_down_date[i].weekday() == 0:
            if ((npc_down_date[i] - timedelta(days=3)) == date) and tmp[1] > "13:30:00":
                df_npc_down_news.loc[down_index] = row
                down_index += 1
            elif((npc_down_date[i] - timedelta(days=2)) == date or (npc_down_date[i] - timedelta(days=2)) == date):
                df_npc_down_news.loc[down_index] = row
                down_index += 1
            elif ((npc_down_date[i]) == date) and tmp[1] < "13:30:00":
                df_npc_down_news.loc[down_index] = row
                down_index += 1
        else:
            if ((npc_down_date[i] - timedelta(days=1)) == date) and tmp[1] > "13:30:00":
                df_npc_down_news.loc[down_index] = row
                down_index += 1
            elif ((npc_down_date[i]) == date) and tmp[1] < "13:30:00":
                df_npc_down_news.loc[down_index] = row
                down_index += 1

# %%
df_npc_down_news
# Out:
#                     id            post_time  \
# 0    1451725007435_N01    2016/1/2 16:32:00
# 1    1451869007598_N01    2016/1/4 08:29:00
# 2    1451869015197_N01    2016/1/4 08:35:00
# 3    1451875308676_N01    2016/1/4 10:23:00
# 4    1451879808470_N01    2016/1/4 11:34:00
# 5    1453291979529_N01   2016/1/20 19:40:00
# 6    1453336981819_N01   2016/1/21 08:29:00
# 7    1453338783776_N01   2016/1/21 08:43:00
# 8    1453352279497_N01   2016/1/21 12:30:00
# 9    1456128478303_N01   2016/2/22 15:50:00
# 10   1458868191824_N01   2016/3/25 08:41:00
# 11   1458868196896_N01   2016/3/25 08:47:00
# 12   1458879006685_N01   2016/3/25 12:00:00
# 13   1461112763129_N01   2016/4/20 08:11:00
# 14   1461115457597_N01   2016/4/20 08:57:00
# 15   1461739952121_N01   2016/4/27 14:34:00
# 16   1461742640136_N01   2016/4/27 15:11:00
# 17   1461802049048_N01   2016/4/28 07:47:00
# 18   1461802940042_N01   2016/4/28 07:57:00
# 19   1462235475665_N01    2016/5/3 08:00:00
# ...

# %%
with pd.ExcelWriter("company_up_down_news(2016~2018).xlsx") as writer:
    df_tsmc_up_news.to_excel(writer, sheet_name="TSMC_up")
    df_tsmc_down_news.to_excel(writer, sheet_name="TSMC_down")
    df_foxconn_up_news.to_excel(writer, sheet_name="Foxconn_up")
    df_foxconn_down_news.to_excel(writer, sheet_name="Foxconn_down")
    df_fpc_up_news.to_excel(writer, sheet_name="FPC_up")
    df_fpc_down_news.to_excel(writer, sheet_name="FPC_down")
    df_largan_up_news.to_excel(writer, sheet_name="大立光_up")
    df_largan_down_news.to_excel(writer, sheet_name="大立光_down")
    df_mtk_up_news.to_excel(writer, sheet_name="聯發科_up")
    df_mtk_down_news.to_excel(writer, sheet_name="聯發科_down")
    df_cht_up_news.to_excel(writer, sheet_name="中華電_up")
    df_cht_down_news.to_excel(writer, sheet_name="中華電_down")
    df_ctbc_up_news.to_excel(writer, sheet_name="中信金_up")
    df_ctbc_down_news.to_excel(writer, sheet_name="中信金_down")
    df_fcfc_up_news.to_excel(writer, sheet_name="台化_up")
    df_fcfc_down_news.to_excel(writer, sheet_name="台化_down")
    df_uni_up_news.to_excel(writer, sheet_name="統一_up")
    df_uni_down_news.to_excel(writer, sheet_name="統一_down")
    df_cathay_up_news.to_excel(writer, sheet_name="國泰金_up")
    df_cathay_down_news.to_excel(writer, sheet_name="國泰金_down")
    df_npc_up_news.to_excel(writer, sheet_name="南亞_up")
    df_npc_down_news.to_excel(writer, sheet_name="南亞_down")
